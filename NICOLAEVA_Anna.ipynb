# %% [markdown]
# <a href="https://colab.research.google.com/github/arnautoleg/R/blob/main/NICOLAEVA_Anna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Dataset formation

# %%
df = pd.read_excel('/content/statistica urgente nicolaev diagram.xlsx')

# %%
df.shape
# Out:
# (4539, 14)

# %%
df.columns
# Out:
# Index(['Nr.', 'N.P.', 'LOT', 'Diagnoza', 'Sex', 'Varsta', 'Urban / Rural',
#        'Asigurat', 'Debut (zile)', 'Temperatura', 'TA (mmHg) sistolică',
#        'Spitalizare (zile)', 'Unnamed: 12', 'FO'],
#       dtype='object')

# %%
df = df [['Diagnoza', 'Sex', 'Varsta', 'Spitalizare (zile)', 'Unnamed: 12', 'FO']]
df.columns = ['Diagnoza', 'Sex', 'Varsta', 'Spitalizare (zile)', 'Rezultat', 'FO']
df
# Out:
#                                                Diagnoza   Sex  Varsta  \
# 0     L040 - Limfadenita acuta a fetei, capului si g...  masc      38
# 1     L040 - Limfadenita acuta a fetei, capului si g...   fem      32
# 2     L040 - Limfadenita acuta a fetei, capului si g...   fem      68
# 3     L040 - Limfadenita acuta a fetei, capului si g...   fem      28
# 4     L040 - Limfadenita acuta a fetei, capului si g...  masc      20
# ...                                                 ...   ...     ...
# 4534                     J010 - Sinuzita maxilara acuta   fem      35
# 4535                     J010 - Sinuzita maxilara acuta  masc      42
# 4536                     J010 - Sinuzita maxilara acuta   fem      38
# 4537                     J010 - Sinuzita maxilara acuta   fem      47
# 4538                     J010 - Sinuzita maxilara acuta   fem      32
#
#       Spitalizare (zile)  Rezultat       FO
# 0                     11  externat  1800297
# ...

# %%
df.Diagnoza.value_counts(normalize=True)
# Out:
# K122 - Flegmonul si abcesul gurii                                0.389072
# L032 - Flegmonul fetei                                           0.205111
# L020 - Abces cutanat, furuncul si furuncul antracoid al fetei    0.195197
# L040 - Limfadenita acuta a fetei, capului si gitului             0.096938
# K102 - Afectiuni inflamatorii ale maxilarelor                    0.037673
# J320 - Sinuzita maxilara cronica                                 0.027098
# J010 - Sinuzita maxilara acuta                                   0.022913
# K112 - Sialoadenita                                              0.014100
# K052 - Periodontita acuta                                        0.011677
# K045 - Periodontita apicala cronica                              0.000220
# Name: Diagnoza, dtype: float64

# %%
df.Sex.value_counts(normalize=True)
# Out:
# masc    0.525887
# fem     0.474113
# Name: Sex, dtype: float64

# %%
df[['Varsta', 'Spitalizare (zile)']].hist()
# Out:
# array([[<Axes: title={'center': 'Varsta'}>,
#         <Axes: title={'center': 'Spitalizare (zile)'}>]], dtype=object)

# %%
df.Rezultat.value_counts(normalize=True)
# Out:
# externat                      0.985019
# Decedat in Reanimare          0.006389
# externat la cerere            0.003966
# Decedat in TI                 0.003305
# decedat in sectie             0.000661
# transfer inter-spitalicesc    0.000441
# Decedat in izolator           0.000220
# Name: Rezultat, dtype: float64

# %%
df1 = pd.read_excel('/content/statistica urgente nicolaev diagram.xlsx', sheet_name='Fisele din plaga')

# %%
df1.columns = [['FO']]
df1
# Out:
#           FO
# 0      24443
# 1    1800065
# 2    1800306
# 3    1800390
# 4    1800423
# ..       ...
# 977  2323197
# 978  2323173
# 979  2323596
# 980  2323598
# 981  2323657
#
# [982 rows x 1 columns]

# %%
rows = [x[0] for x in df1.FO.values]

# %%
df = df[df['FO'].isin(rows)]

# %%
df3 = pd.read_excel('/content/statistica urgente nicolaev diagram.xlsx', sheet_name='antibioticograma')
df3 = df3[['FO',	'Material',	'Microorganism',	'Antibiotoc',	'Rezistenta']]
df3
# Out:
#             FO           Material               Microorganism  \
# 0        24526  Secrete din plaga  Staphylococcus epidermidis
# 1        24526  Secrete din plaga  Staphylococcus epidermidis
# 2        24526  Secrete din plaga  Staphylococcus epidermidis
# 3        24526  Secrete din plaga  Staphylococcus epidermidis
# 4        24526  Secrete din plaga  Staphylococcus epidermidis
# ...        ...                ...                         ...
# 19047  2323657            Punctat       Enterococcus faecalis
# 19048  2323657            Punctat       Enterococcus faecalis
# 19049  2323657            Punctat       Enterococcus faecalis
# 19050  2323657            Punctat       Enterococcus faecalis
# 19051  2323657            Punctat       Enterococcus faecalis
#
#                           Antibiotoc Rezistenta
# 0                       ERYTHROMYCIN          S
# 1                          CEFOXITIN          S
# 2                      CIPROFLOXACIN          S
# ...

# %%
df3.Material.value_counts()
# Out:
# Secrete din plaga                14181
# Secret din caile respiratorii     1929
# din plaga                          973
# Urina                              780
# Singe                              497
# Punctat                            295
# Exudat                             205
# Sputa                               58
# Secret faringean                    51
# Secrete din vagin                   33
# Patologie                            6
# Name: Material, dtype: int64

# %%
df3 = df3[df3['Material'].isin(['Secrete din plaga', 'din plaga', 'Punctat', 'Exudat'])]
df3.drop(['Material'], axis=1, inplace=True)
df3
# Out:
# <ipython-input-426-1f1e1be6c840>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop(['Material'], axis=1, inplace=True)
#             FO               Microorganism                     Antibiotoc  \
# 0        24526  Staphylococcus epidermidis                   ERYTHROMYCIN
# 1        24526  Staphylococcus epidermidis                      CEFOXITIN
# 2        24526  Staphylococcus epidermidis                  CIPROFLOXACIN
# 3        24526  Staphylococcus epidermidis                  MOXIFLOXACINA
# 4        24526  Staphylococcus epidermidis                   LEVOFLOXACIN
# ...        ...                         ...                            ...
# 19047  2323657       Enterococcus faecalis                       IMIPENEM
# ...

# %%
import numpy as np

# %%
type('ERYTHROMYCIN')
# Out:
# str

# %%
tabel = pd.read_excel('/content/таблица.xlsx')

original = []
change   = []

for col in tabel.columns:
  values = [el.upper() for el in tabel[col].unique() if type(el) == str]
  #print(values)
  original.extend(values)
  change.extend([col] * len(values))

print(original)
print(change)

len(original) == len(change)
# Out:
# ['ERYTHROMYCIN', 'CLARITROMICINA', 'AZITROMICINA', 'CEFALEXINA', 'CEFAZOLIN', 'CEFOXITIN', 'CEFUROXIME', 'CEPHALOTIN', 'CEFACLOR', 'CEFTRIAXONE', 'CEFOPERAZONE', 'CEFIXIME', 'CEFOTAXIME', 'CEFTAZIDIME', 'CEFEPIME', 'CIPROFLOXACIN', 'MOXIFLOXACINA', 'LEVOFLOXACINA', 'LOMEFLOXACIN', 'GENTAMICIN', 'AMIKACIN', 'NETILMICIN', 'STREPTOMICIN', 'TOBRAMYCIN', 'NITROFURANTOIN', 'TRIMETHOPRIM', 'DOXYCYCLINE', 'TIGECYCLINE', 'TETRACYCLINE', 'BENZILPENICILINA', 'AMPICILLIN', 'AMOXICILLIN', 'OXACILLIN', 'TICARCILLIN', 'CARBENICILLIN', 'LINEZOLID ', 'LINEZOLID', 'PIPERACILLIN', 'NORFLOXACIN', 'OFLOXACIN', 'PEPIMIDIC ACID', 'VANCOMYCIN', 'TEICOPLANIN', 'RIFAMPICINA', 'NISTATINA', 'LINCOMYCIN', 'CLINDAMYCIN', 'ERTAPENEM', 'MEROPENEM', 'IMIPENEM', 'ERTAPENEM ', 'AZTREONAM', 'AMOXYCLAV', 'CEFOPERAZONE/SULBACTAM', 'PIPERACILLIN/SULBACTAM', 'PIPERACILLIN/TAZOBACTA', 'AMPICILLIN/SULBACTAM', 'COLISTIN', 'POLYMIXIN', 'FOSFOMYCIN', 'TRIMETHOPRIM/SULFA', 'TRIMETHOPRIM/SULFAMETHOXAZOLE', 'CHLORAMPHENICOL']
# ...

# %%
df3.Antibiotoc = df3.Antibiotoc.replace(original, change)
# Out:
# <ipython-input-430-80044373e04d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.Antibiotoc = df3.Antibiotoc.replace(original, change)

# %%
df
# Out:
#                                                Diagnoza   Sex  Varsta  \
# 20    L040 - Limfadenita acuta a fetei, capului si g...  masc      22
# 48    L040 - Limfadenita acuta a fetei, capului si g...  masc      50
# 49    L040 - Limfadenita acuta a fetei, capului si g...   fem      54
# 78    L040 - Limfadenita acuta a fetei, capului si g...   fem      65
# 99    L040 - Limfadenita acuta a fetei, capului si g...  masc      45
# ...                                                 ...   ...     ...
# 4417                   J320 - Sinuzita maxilara cronica   fem      62
# 4420                   J320 - Sinuzita maxilara cronica  masc      49
# 4446                     J010 - Sinuzita maxilara acuta   fem      29
# 4492                     J010 - Sinuzita maxilara acuta   fem      19
# 4537                     J010 - Sinuzita maxilara acuta   fem      47
#
#       Spitalizare (zile)  Rezultat       FO
# 20                     3  externat  1803968
# ...

# %%
df3['Antibiotic_Sens'] = df3['Antibiotoc'].astype(str) +  "__" + df3['Rezistenta'].astype(str)
# Out:
# <ipython-input-432-82d0de06bc10>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Antibiotic_Sens'] = df3['Antibiotoc'].astype(str) +  "__" + df3['Rezistenta'].astype(str)

# %%
df3 = df3[df3['Rezistenta'].isin(['S', 'R', 'I', 's', 'SYN-S', 'SS', '  S', '  R', 'SYN-R'])]

df3.replace(['s', 'SYN-S', 'SS', '  S', '  R', 'SYN-R'], ['S', 'S', 'S', 'S', 'R', 'R'], inplace=True)
# Out:
# <ipython-input-433-2adf2b849fda>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.replace(['s', 'SYN-S', 'SS', '  S', '  R', 'SYN-R'], ['S', 'S', 'S', 'S', 'R', 'R'], inplace=True)

# %%
df3.Rezistenta.value_counts()
# Out:
# S    10828
# R     2352
# I      654
# Name: Rezistenta, dtype: int64

# %%
print(df3.shape)
df3 = df3.drop_duplicates(subset=['FO',	'Microorganism',	'Antibiotoc',	'Rezistenta'])
print(df3.shape)
# Out:
# (13834, 5)
# (9042, 5)

# %%
df3[df3['FO'].isin([1808428, 1923481])].pivot(index = 'FO', columns = 'Antibiotoc', values = 'Rezistenta').T
# Out:
# FO                                                 1808428 1923481
# Antibiotoc
# Aminoglicozide                                           S     NaN
# Ansamicine                                               S     NaN
# Asociere de beta-lactamine si inhibitori de bet...     NaN       S
# Cefalosporine                                            S     NaN
# Chinolone                                              NaN       S
# Chloramphenicol                                          R     NaN
# Fluorochinolone                                          S       S
# Glicopeptide                                           NaN       S
# LEVOFLOXACIN                                             S     NaN
# Lincosamide                                            NaN       S
# Macrolide                                                S       S
# Nitrofurani                                              S     NaN
# Peniciline                                             NaN       S
# ...

# %%
print(df3[df3.Antibiotoc=='LEVOFLOXACIN'].Antibiotoc.value_counts())
df3.Antibiotoc = df3.Antibiotoc.replace(['LEVOFLOXACIN'], ['Fluorochinolone'])
print(df3[df3.Antibiotoc=='LEVOFLOXACIN'].Antibiotoc.value_counts())
# Out:
# LEVOFLOXACIN    657
# Name: Antibiotoc, dtype: int64
# Series([], Name: Antibiotoc, dtype: int64)

# %%
df3.Antibiotoc.value_counts()
# Out:
# Fluorochinolone                                               1677
# Peniciline                                                    1039
# Macrolide                                                      946
# Cefalosporine                                                  906
# Asociere de beta-lactamine si inhibitori de beta-lactamaze     637
# Aminoglicozide                                                 629
# Glicopeptide                                                   619
# Lincosamide                                                    490
# Chinolone                                                      488
# Tetracicline                                                   389
# Sulfanialamide                                                 266
# Chloramphenicol                                                227
# Ansamicine                                                     182
# Carbapenemi                                                    154
# ...

# %%
values_to_drop = ['FUSIDIC ACID',
                  'KETOCONAZOL','FLUCONAZOLE','MICONAZOL','CLOTRIMAZOL',
                  'VORICONAZOL','STREPTOMYCIN HIGH LEVEL (SYNERGY)','STREP_MIC',
                  'ITRACONAZOLE ','TICARCILLIN/CA', 'PIPEMIDIC ACID']


#df3.drop(df3[df3.Antibiotoc.isin(remove)], axis = 0, inplace = True)


# Drop rows based on multiple conditions and the list of values
df3 = df3[~df3['Antibiotoc'].isin(values_to_drop)]

# df_filtered now contains the DataFrame with rows removed based on the specified conditions

# %%
df3.Antibiotoc.value_counts()
# Out:
# Fluorochinolone                                               1677
# Peniciline                                                    1039
# Macrolide                                                      946
# Cefalosporine                                                  906
# Asociere de beta-lactamine si inhibitori de beta-lactamaze     637
# Aminoglicozide                                                 629
# Glicopeptide                                                   619
# Lincosamide                                                    490
# Chinolone                                                      488
# Tetracicline                                                   389
# Sulfanialamide                                                 266
# Chloramphenicol                                                227
# Ansamicine                                                     182
# Carbapenemi                                                    154
# ...

# %%
df4 = df3.groupby('FO')['FO', 'Microorganism'].head(1).reset_index(drop=True)
# Out:
# <ipython-input-441-dbf0e042797e>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df4 = df3.groupby('FO')['FO', 'Microorganism'].head(1).reset_index(drop=True)

# %%
df4
# Out:
#           FO                 Microorganism
# 0      24526    Staphylococcus epidermidis
# 1      24443       Streptococcus sanguinis
# 2    1800065         Streptococcus group G
# 3    1800306    Staphylococcus epidermidis
# 4    1800390              Escherichia coli
# ..       ...                           ...
# 978  2323197    Staphylococcus epidermidis
# 979  2323173    Staphylococcus epidermidis
# 980  2323596  Staphylococcus saprophyticus
# 981  2323598  Staphylococcus saprophyticus
# 982  2323657         Enterococcus faecalis
#
# [983 rows x 2 columns]

# %%
#df_final = pd.merge(df3, df4)

df5=df4.merge(df3, left_on=['FO',	'Microorganism'], right_on=['FO',	'Microorganism'])

# %%
df5=df5.pivot_table(index = 'FO', columns = 'Antibiotoc', values = 'Rezistenta', aggfunc='first')

df5
# Out:
# Antibiotoc Alfa-antibiotice Aminoglicozide Ansamicine  \
# FO
# 24443                   NaN            NaN        NaN
# 24526                   NaN              S        NaN
# 1291431                 NaN            NaN        NaN
# 1800065                 NaN            NaN          S
# 1800306                 NaN              S          S
# ...                     ...            ...        ...
# 2323173                 NaN              S        NaN
# 2323197                 NaN              S        NaN
# 2323596                 NaN              S        NaN
# 2323598                 NaN              S        NaN
# 2323657                 NaN            NaN        NaN
#
# Antibiotoc Asociere de beta-lactamine si inhibitori de beta-lactamaze  \
# FO
# 24443                                                       S
# 24526                                                     NaN
# 1291431                                                     S
# ...

# %%
df6=df5.merge(df4, left_on=['FO'], right_on=['FO'])
df6
# Out:
#           FO Alfa-antibiotice Aminoglicozide Ansamicine  \
# 0      24443              NaN            NaN        NaN
# 1      24526              NaN              S        NaN
# 2    1291431              NaN            NaN        NaN
# 3    1800065              NaN            NaN          S
# 4    1800306              NaN              S          S
# ..       ...              ...            ...        ...
# 978  2323173              NaN              S        NaN
# 979  2323197              NaN              S        NaN
# 980  2323596              NaN              S        NaN
# 981  2323598              NaN              S        NaN
# 982  2323657              NaN            NaN        NaN
#
#     Asociere de beta-lactamine si inhibitori de beta-lactamaze Carbapenemi  \
# 0                                                    S                 NaN
# 1                                                  NaN                 NaN
# ...

# %%
df_final=df6.merge(df, left_on=['FO'], right_on=['FO'])
df_final
# Out:
#           FO Alfa-antibiotice Aminoglicozide Ansamicine  \
# 0      24443              NaN            NaN        NaN
# 1    1291431              NaN            NaN        NaN
# 2    1800065              NaN            NaN          S
# 3    1800306              NaN              S          S
# 4    1800390              NaN              S        NaN
# ..       ...              ...            ...        ...
# 979  2323173              NaN              S        NaN
# 980  2323197              NaN              S        NaN
# 981  2323596              NaN              S        NaN
# 982  2323598              NaN              S        NaN
# 983  2323657              NaN            NaN        NaN
#
#     Asociere de beta-lactamine si inhibitori de beta-lactamaze Carbapenemi  \
# 0                                                    S                 NaN
# 1                                                    S                 NaN
# ...

# %%
df_final.columns
# Out:
# Index(['FO', 'Alfa-antibiotice', 'Aminoglicozide', 'Ansamicine',
#        'Asociere de beta-lactamine si inhibitori de beta-lactamaze',
#        'Carbapenemi', 'Cefalosporine', 'Chinolone', 'Chloramphenicol',
#        'Diaminopirimidine', 'Fluorochinolone', 'Glicopeptide', 'Lincosamide',
#        'Macrolide', 'Monobactami', 'Nitrofurani', 'Peniciline', 'Poliene',
#        'Polipeptide', 'Sulfanialamide', 'Tetracicline', 'Microorganism',
#        'Diagnoza', 'Sex', 'Varsta', 'Spitalizare (zile)', 'Rezultat'],
#       dtype='object')

# %%
df_final.fillna('N', inplace= True )

# %%
df_final.isna().sum()
# Out:
# FO                                                            0
# Alfa-antibiotice                                              0
# Aminoglicozide                                                0
# Ansamicine                                                    0
# Asociere de beta-lactamine si inhibitori de beta-lactamaze    0
# Carbapenemi                                                   0
# Cefalosporine                                                 0
# Chinolone                                                     0
# Chloramphenicol                                               0
# Diaminopirimidine                                             0
# Fluorochinolone                                               0
# Glicopeptide                                                  0
# Lincosamide                                                   0
# Macrolide                                                     0
# Monobactami                                                   0
# ...

# %%
df_final.Aminoglicozide.value_counts()
# Out:
# N    538
# S    385
# R     58
# I      3
# Name: Aminoglicozide, dtype: int64

# %%
df_final.drop('FO', axis=1, inplace = True)

# %% [markdown]
# # EDA

# %%
df_final.head()
# Out:
#   Alfa-antibiotice Aminoglicozide Ansamicine  \
# 0                N              N          N
# 1                N              N          N
# 2                N              N          S
# 3                N              S          S
# 4                N              S          N
#
#   Asociere de beta-lactamine si inhibitori de beta-lactamaze Carbapenemi  \
# 0                                                  S                   N
# 1                                                  S                   N
# 2                                                  S                   N
# 3                                                  N                   N
# 4                                                  S                   N
#
#   Cefalosporine Chinolone Chloramphenicol Diaminopirimidine Fluorochinolone  \
# 0             S         S               S                 N               S
# 1             S         N               S                 N               S
# ...

# %%
df_final.Rezultat.value_counts()
# Out:
# externat                      946
# Decedat in Reanimare           24
# Decedat in TI                  10
# decedat in sectie               2
# transfer inter-spitalicesc      1
# externat la cerere              1
# Name: Rezultat, dtype: int64

# %%
df_final.replace(['Decedat in Reanimare', 'Decedat in TI', 'decedat in sectie'], ['decedat', 'decedat', 'decedat'], inplace=True)
df_final.Rezultat.value_counts()
# Out:
# externat                      946
# decedat                        36
# transfer inter-spitalicesc      1
# externat la cerere              1
# Name: Rezultat, dtype: int64

# %%
df_final = df_final[df_final['Rezultat'].isin(['externat', 'decedat'])]
round(df_final.Rezultat.value_counts(normalize=True), 3)
# Out:
# externat    0.963
# decedat     0.037
# Name: Rezultat, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'Category': ['Externat', 'Decedat'],
    'Percentage': [96.3, 3.7]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Calculate the total percentage
total_percentage = df['Percentage'].sum()

# Calculate the percentage for each category
df['Percentage'] = (df['Percentage'] / total_percentage) * 100

# Create a bar plot
sns.barplot(x='Category', y='Percentage', data=df)

# Add labels to the bars
for index, row in df.iterrows():
    plt.text(row.name, row.Percentage, f'{row.Percentage:.1f}%', ha='center', va='bottom')

# Set plot labels and title
plt.xlabel('Category')
plt.ylabel('%')
plt.title('Rezultatele tratamentului')

# Show the plot
plt.show()

# %%
round(df_final.Sex.value_counts(normalize=True), 3)
# Out:
# masc    0.612
# fem     0.388
# Name: Sex, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'Category': ['M', 'F'],
    'Percentage': [61.2, 38.8]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Calculate the total percentage
total_percentage = df['Percentage'].sum()

# Calculate the percentage for each category
df['Percentage'] = (df['Percentage'] / total_percentage) * 100

# Create a bar plot
sns.barplot(x='Category', y='Percentage', data=df)

# Add labels to the bars
for index, row in df.iterrows():
    plt.text(row.name, row.Percentage, f'{row.Percentage:.1f}%', ha='center', va='bottom')

# Set plot labels and title
plt.xlabel('Category')
plt.ylabel('%')
plt.title('Distributia dupa genul biologic')

# Show the plot
plt.show()

# %%
df_final.Microorganism.value_counts(normalize=True)
# Out:
# Staphylococcus epidermidis                          0.324847
# Streptococcus group G                               0.185336
# Streptococcus group C                               0.106925
# Staphylococcus aureus                               0.051935
# Streptococcus pyogenes                              0.051935
# Streptococcus anginosus                             0.038697
# Staphylococcus haemolyticus                         0.033605
# Streptococcus group B                               0.027495
# Streptococcus mitis                                 0.023422
# Streptococcus sanguinis                             0.021385
# Enterococcus faecalis                               0.020367
# Enterococcus spp                                    0.014257
# Streptococcus group A                               0.013238
# Klebsiella pneumoniae                               0.009165
# Kocuria kristinae                                   0.008147
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'Category': ['Staphylococcus epidermidis', 'Streptococcus group G',
       'Streptococcus group C', 'Staphylococcus aureus',
       'Streptococcus pyogenes', 'Streptococcus anginosus',
       'Staphylococcus haemolyticus', 'Streptococcus group B',
       'Streptococcus mitis', 'Streptococcus sanguinis',
       'Enterococcus faecalis', 'Enterococcus spp', 'Streptococcus group A',
       'Klebsiella pneumoniae', 'Kocuria kristinae', 'Acinetobacter baumannii',
       'Escherichia coli', 'Streptococcus mitis/Streptococcus oralis',
       'Streptococcus agalactiae', 'Kocuria rosea', 'Pseudomonas aeruginosa',
       'Streptococcus constellatus ssp constellatus', 'Streptococcus mutans',
       'Streptococcus constellatus', 'Staphylococcus saprophyticus',
       'Streptococcus parasanguinis', 'Streptococcus gordonii',
       'Candida albicans', 'Streptococcus salivarius',
       'Streptococcus intermedius', 'Streptococcus constellatus ssp pharyngis',
       'Streptococcus porcinus', 'Enterococcus faecium', 'Neisseria sicca',
       'Bacillus megaterium', 'Sphingomonas paucimobilis',
       'Streptococcus pneumoniae',
       'Streptococcus viridans group except S.pneumoniae',
       'Staphylococcus intermedius', 'Staphylococcus hominis ssp hominis',
       'Candida glabrata', 'Enterococcus durans'],
    'Percentage': [32.48472505, 18.53360489, 10.69246436,  5.19348269,  5.19348269,
        3.86965377,  3.3604888 ,  2.74949084,  2.34215886,  2.13849287,
        2.03665988,  1.42566191,  1.32382892,  0.91649695,  0.81466395,
        0.71283096,  0.61099796,  0.50916497,  0.50916497,  0.30549898,
        0.30549898,  0.30549898,  0.30549898,  0.30549898,  0.30549898,
        0.30549898,  0.20366599,  0.20366599,  0.20366599,  0.20366599,
        0.20366599,  0.20366599,  0.20366599,  0.20366599,  0.10183299,
        0.10183299,  0.10183299,  0.10183299,  0.10183299,  0.10183299,
        0.10183299,  0.10183299]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Calculate the total percentage
total_percentage = df['Percentage'].sum()

# Calculate the percentage for each category
df['Percentage'] = (df['Percentage'] / total_percentage) * 100
plt.figure(figsize=(10, 10))
# Create a bar plot
sns.barplot(x='Percentage', y='Category', data=df)

# Add labels to the bars
#for index, row in df.iterrows():
#    plt.text(row.name, row.Percentage, f'{row.Percentage:.1f}%', ha='center', va='bottom')

# Set plot labels and title
plt.xlabel('%')
plt.ylabel('Agentul patogen')
plt.title('Distributia dupa agentul patogen')


# Show the plot
plt.show()

# %%
round(df_final.Diagnoza.value_counts(normalize=True), 3)
# Out:
# L032 - Flegmonul fetei                                           0.574
# K122 - Flegmonul si abcesul gurii                                0.227
# L020 - Abces cutanat, furuncul si furuncul antracoid al fetei    0.136
# L040 - Limfadenita acuta a fetei, capului si gitului             0.039
# K102 - Afectiuni inflamatorii ale maxilarelor                    0.013
# J320 - Sinuzita maxilara cronica                                 0.004
# K112 - Sialoadenita                                              0.003
# J010 - Sinuzita maxilara acuta                                   0.003
# Name: Diagnoza, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'Category': ['L032', 'K122', 'L020', 'L040', 'K102', 'J320', 'K112', 'J010'],
    'Percentage': [57.4, 22.7, 13.6, 3.9, 1.3, 0.4, 0.3, 0.3]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Calculate the total percentage
total_percentage = df['Percentage'].sum()

# Calculate the percentage for each category
df['Percentage'] = (df['Percentage'] / total_percentage) * 100

# Create a bar plot
sns.barplot(x='Category', y='Percentage', data=df)

# Add labels to the bars
for index, row in df.iterrows():
    plt.text(row.name, row.Percentage, f'{row.Percentage:.1f}%', ha='center', va='bottom')

# Set plot labels and title
plt.xlabel('Category')
plt.ylabel('%')
plt.title('Distributia dupa diagnoza')

# Show the plot
plt.show()

# %%
df_final['Spitalizare (zile)'].hist();

# %%
df_final['Spitalizare (zile)'].describe()
# Out:
# count    982.000000
# mean       7.254582
# std        6.053478
# min        0.000000
# 25%        4.000000
# 50%        5.000000
# 75%        8.000000
# max       62.000000
# Name: Spitalizare (zile), dtype: float64

# %%
df_final['Varsta'].hist();

# %%
df_final['Varsta'].describe()
# Out:
# count    982.000000
# mean      43.861507
# std       15.996533
# min       18.000000
# 25%       31.000000
# 50%       41.000000
# 75%       55.000000
# max       90.000000
# Name: Varsta, dtype: float64

# %%
df_final.columns
# Out:
# Index(['Alfa-antibiotice', 'Aminoglicozide', 'Ansamicine',
#        'Asociere de beta-lactamine si inhibitori de beta-lactamaze',
#        'Carbapenemi', 'Cefalosporine', 'Chinolone', 'Chloramphenicol',
#        'Diaminopirimidine', 'Fluorochinolone', 'Glicopeptide', 'Lincosamide',
#        'Macrolide', 'Monobactami', 'Nitrofurani', 'Peniciline', 'Poliene',
#        'Polipeptide', 'Sulfanialamide', 'Tetracicline', 'Microorganism',
#        'Diagnoza', 'Sex', 'Varsta', 'Spitalizare (zile)', 'Rezultat'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import chi2_contingency
import matplotlib.pyplot as plt

# Create a sample 2x2 contingency table
data = {
    'Deces': [14, 22],
    'Externat': [367, 579]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Perform the chi-squared test
chi2, p, _, _ = chi2_contingency(df)

# Create a heatmap to visualize the contingency table
plt.figure(figsize=(6, 4))

# Specify custom y-axis labels
y_labels = ['M', 'F']

# Create the heatmap with custom y-axis labels
sns.heatmap(df, annot=True, cmap="YlGnBu", fmt="d", cbar=False, yticklabels=y_labels)

# Add the chi-squared test result to the plot
plt.text(0.75, 0.9, f"Chi-Squared Statistic: {chi2:.2f}\nP-value: {p:.4f}",
         fontsize=12, ha="center", va="center", transform=plt.gca().transAxes)

# Set plot labels and title
plt.xlabel('Result')
plt.ylabel('Sex')
plt.title('2x2 Contingency Table Heatmap')

plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Create a sample 8x2 table
data = {
    'Deces':    [20, 9, 4, 3, 0, 0, 0, 0],
    'Externat': [544, 214, 130, 35, 13, 4, 3, 3],
}

# Create a DataFrame
df = pd.DataFrame(data)

# Perform the chi-squared test
chi2, p, _, _ = chi2_contingency(df)


# Create a heatmap to visualize the table
plt.figure(figsize=(8, 4))  # Adjust the figure size as needed

# Specify custom y-axis labels
y_labels = ['L032', 'K122', 'L020', 'L040', 'K102', 'J320', 'J010', 'K112']

sns.heatmap(df, annot=True, cmap="YlGnBu", fmt="d", cbar=True, yticklabels=y_labels)

# Add the chi-squared test result to the plot
plt.text(0.5, 0.5, f"Chi-Squared Statistic: {chi2:.2f}\nP-value: {p:.4f}",
         fontsize=12, ha="center", va="center", transform=plt.gca().transAxes)


# Set plot labels and title
plt.xlabel('Rezultat')
plt.ylabel('Diagnoza')
plt.title('Heatmap for an 8x2 Table')

plt.show()

# %%
df_final.columns
# Out:
# Index(['Alfa-antibiotice', 'Aminoglicozide', 'Ansamicine',
#        'Asociere de beta-lactamine si inhibitori de beta-lactamaze',
#        'Carbapenemi', 'Cefalosporine', 'Chinolone', 'Chloramphenicol',
#        'Diaminopirimidine', 'Fluorochinolone', 'Glicopeptide', 'Lincosamide',
#        'Macrolide', 'Monobactami', 'Nitrofurani', 'Peniciline', 'Poliene',
#        'Polipeptide', 'Sulfanialamide', 'Tetracicline', 'Microorganism',
#        'Diagnoza', 'Sex', 'Varsta', 'Spitalizare (zile)', 'Rezultat'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu


# Create a box plot to compare the two groups
plt.figure(figsize=(6, 4))
sns.boxplot(x='Rezultat', y='Varsta', data=df_final)
plt.xlabel('Rezultat')
plt.ylabel('Varsta')
plt.title('Comparative Evaluation Between Two Groups')

# Perform Mann-Whitney U test
group_A = df_final[df_final['Rezultat'] == 'externat']['Varsta']
group_B = df_final[df_final['Rezultat'] == 'decedat']['Varsta']
statistic, p_value = mannwhitneyu(group_A, group_B, alternative='two-sided')

# Add the Mann-Whitney U test result to the plot
result_text = f'Mann-Whitney U Test\np-value = {p_value:.4f}'
plt.text(0.5, 0.85, result_text, fontsize=10, ha='center', va='center', transform=plt.gca().transAxes)

plt.show()

# %%
df_final.groupby('Rezultat').Varsta.describe()
# Out:
#           count       mean        std   min    25%   50%   75%   max
# Rezultat
# decedat    36.0  63.083333  17.793056  30.0  49.75  68.5  75.0  90.0
# externat  946.0  43.130021  15.469342  18.0  31.00  40.0  54.0  89.0

# %%
import pandas as pd
from scipy.stats import chi2_contingency


# Create a contingency table
contingency_table = pd.crosstab(df_final['Microorganism'], df_final['Rezultat'])

# Perform the chi-squared test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Display the contingency table
print("Contingency Table:")
print(contingency_table)

# Display the chi-squared test result
print("\nChi-Squared Statistic:", chi2)
print("P-value:", p)
print("Degrees of Freedom:", dof)
# Out:
# Contingency Table:
# Rezultat                                          decedat  externat
# Microorganism
# Acinetobacter baumannii                                 1         6
# Bacillus megaterium                                     0         1
# Candida albicans                                        0         2
# Candida glabrata                                        0         1
# Enterococcus durans                                     0         1
# Enterococcus faecalis                                   1        19
# Enterococcus faecium                                    0         2
# Enterococcus spp                                        0        14
# Escherichia coli                                        0         6
# Klebsiella pneumoniae                                   0         9
# Kocuria kristinae                                       0         8
# Kocuria rosea                                           0         3
# ...

# %%
df_final.columns
# Out:
# Index(['Alfa-antibiotice', 'Aminoglicozide', 'Ansamicine',
#        'Asociere de beta-lactamine si inhibitori de beta-lactamaze',
#        'Carbapenemi', 'Cefalosporine', 'Chinolone', 'Chloramphenicol',
#        'Diaminopirimidine', 'Fluorochinolone', 'Glicopeptide', 'Lincosamide',
#        'Macrolide', 'Monobactami', 'Nitrofurani', 'Peniciline', 'Poliene',
#        'Polipeptide', 'Sulfanialamide', 'Tetracicline', 'Microorganism',
#        'Diagnoza', 'Sex', 'Varsta', 'Spitalizare (zile)', 'Rezultat'],
#       dtype='object')

# %%
df_final['Spitalizare (zile)'].describe()
# Out:
# count    982.000000
# mean       7.254582
# std        6.053478
# min        0.000000
# 25%        4.000000
# 50%        5.000000
# 75%        8.000000
# max       62.000000
# Name: Spitalizare (zile), dtype: float64

# %%
df_final.groupby('Rezultat')['Spitalizare (zile)'].describe()
# Out:
#           count       mean        std  min  25%  50%   75%   max
# Rezultat
# decedat    36.0  13.083333  11.842719  1.0  6.0  8.5  15.0  48.0
# externat  946.0   7.032770   5.612720  0.0  4.0  5.0   8.0  62.0

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu


# Create a box plot to compare the two groups
plt.figure(figsize=(6, 4))
sns.boxplot(x='Rezultat', y='Spitalizare (zile)', data=df_final)
plt.xlabel('Rezultat')
plt.ylabel('Spitalizare (zile)')
plt.title('Comparative Evaluation Between Two Groups')

# Perform Mann-Whitney U test
group_A = df_final[df_final['Rezultat'] == 'externat']['Spitalizare (zile)']
group_B = df_final[df_final['Rezultat'] == 'decedat']['Spitalizare (zile)']
statistic, p_value = mannwhitneyu(group_A, group_B, alternative='two-sided')

# Add the Mann-Whitney U test result to the plot
result_text = f'Mann-Whitney U Test\np-value = {p_value:.4f}'
plt.text(0.5, 0.85, result_text, fontsize=10, ha='center', va='center', transform=plt.gca().transAxes)

plt.show()

# %%
df_final.columns
# Out:
# Index(['Alfa-antibiotice', 'Aminoglicozide', 'Ansamicine',
#        'Asociere de beta-lactamine si inhibitori de beta-lactamaze',
#        'Carbapenemi', 'Cefalosporine', 'Chinolone', 'Chloramphenicol',
#        'Diaminopirimidine', 'Fluorochinolone', 'Glicopeptide', 'Lincosamide',
#        'Macrolide', 'Monobactami', 'Nitrofurani', 'Peniciline', 'Poliene',
#        'Polipeptide', 'Sulfanialamide', 'Tetracicline', 'Microorganism',
#        'Diagnoza', 'Sex', 'Varsta', 'Spitalizare (zile)', 'Rezultat'],
#       dtype='object')

# %%
round(df3.Antibiotoc.value_counts(normalize=True) * 100, 1)
# Out:
# Fluorochinolone                                               18.7
# Peniciline                                                    11.6
# Macrolide                                                     10.6
# Cefalosporine                                                 10.1
# Asociere de beta-lactamine si inhibitori de beta-lactamaze     7.1
# Aminoglicozide                                                 7.0
# Glicopeptide                                                   6.9
# Lincosamide                                                    5.5
# Chinolone                                                      5.5
# Tetracicline                                                   4.3
# Sulfanialamide                                                 3.0
# Chloramphenicol                                                2.5
# Ansamicine                                                     2.0
# Carbapenemi                                                    1.7
# ...

# %%
round(df3.Antibiotoc.value_counts(normalize=True) * 100, 1).index
# Out:
# Index(['Fluorochinolone', 'Peniciline', 'Macrolide', 'Cefalosporine',
#        'Asociere de beta-lactamine si inhibitori de beta-lactamaze',
#        'Aminoglicozide', 'Glicopeptide', 'Lincosamide', 'Chinolone',
#        'Tetracicline', 'Sulfanialamide', 'Chloramphenicol', 'Ansamicine',
#        'Carbapenemi', 'Diaminopirimidine', 'Nitrofurani', 'Alfa-antibiotice',
#        'Polipeptide', 'Monobactami', 'Poliene'],
#       dtype='object')

# %%
round(df3.Antibiotoc.value_counts(normalize=True) * 100, 1).values
# Out:
# array([18.7, 11.6, 10.6, 10.1,  7.1,  7. ,  6.9,  5.5,  5.5,  4.3,  3. ,
#         2.5,  2. ,  1.7,  1.3,  1. ,  0.5,  0.4,  0.1,  0.1])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = {
    'Category': ['Fluorochinolone', 'Peniciline', 'Macrolide', 'Cefalosporine',
       'Asociere de beta-lactamine si inhibitori de beta-lactamaze',
       'Aminoglicozide', 'Glicopeptide', 'Lincosamide', 'Chinolone',
       'Tetracicline', 'Sulfanialamide', 'Chloramphenicol', 'Ansamicine',
       'Carbapenemi', 'Diaminopirimidine', 'Nitrofurani', 'Alfa-antibiotice',
       'Polipeptide', 'Monobactami', 'Poliene'],
    'Percentage': [18.7, 11.6, 10.6, 10.1,  7.1,  7. ,  6.9,  5.5,  5.5,  4.3,  3. ,
                    2.5,  2. ,  1.7,  1.3,  1. ,  0.5,  0.4,  0.1,  0.1]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Calculate the total percentage
total_percentage = df['Percentage'].sum()

# Calculate the percentage for each category
df['Percentage'] = (df['Percentage'] / total_percentage) * 100
plt.figure(figsize=(10, 10))
# Create a bar plot
sns.barplot(x='Percentage', y='Category', data=df)

# Add labels to the bars
#for index, row in df.iterrows():
#    plt.text(row.name, row.Percentage, f'{row.Percentage:.1f}%', ha='center', va='bottom')

# Set plot labels and title
plt.xlabel('%')
plt.ylabel('Preparatul antimicrobian')
plt.title('Distributia dupa preparatul antimicrobian')


# Show the plot
plt.show()

# %%
df_final.columns
# Out:
# Index(['Alfa-antibiotice', 'Aminoglicozide', 'Ansamicine',
#        'Asociere de beta-lactamine si inhibitori de beta-lactamaze',
#        'Carbapenemi', 'Cefalosporine', 'Chinolone', 'Chloramphenicol',
#        'Diaminopirimidine', 'Fluorochinolone', 'Glicopeptide', 'Lincosamide',
#        'Macrolide', 'Monobactami', 'Nitrofurani', 'Peniciline', 'Poliene',
#        'Polipeptide', 'Sulfanialamide', 'Tetracicline', 'Microorganism',
#        'Diagnoza', 'Sex', 'Varsta', 'Spitalizare (zile)', 'Rezultat'],
#       dtype='object')

# %%
df_final.Fluorochinolone.unique()
# Out:
# array(['S', 'R', 'I', 'N'], dtype=object)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from statsmodels.stats.proportion import proportion_confint


for el in ['Fluorochinolone', 'Peniciline', 'Macrolide', 'Cefalosporine',
           'Asociere de beta-lactamine si inhibitori de beta-lactamaze',
           'Aminoglicozide', 'Glicopeptide', 'Lincosamide', 'Chinolone',
           'Tetracicline', 'Sulfanialamide', 'Chloramphenicol', 'Ansamicine',
           'Carbapenemi', 'Diaminopirimidine', 'Nitrofurani', 'Alfa-antibiotice',
           'Polipeptide', 'Monobactami', 'Poliene']:
  # Assuming df is your DataFrame with two categorical variables, 'Comportament Manager' and 'Profesia'
  # Create a contingency table
  contingency_table = pd.crosstab(df_final[el], df_final['Rezultat'])

  # Define the desired order for variables

  variable1_order = ['S', 'R', 'I', 'N']  # Replace with your actual category names

  # Convert variables to CategoricalDtype with specified order
  contingency_table.index = pd.Categorical(contingency_table.index, categories=variable1_order, ordered=True)


  # Sort the index and columns based on the specified order
  contingency_table.sort_index(axis=0, inplace=True)
  contingency_table.sort_index(axis=1, inplace=True)
  contingency_table

  # Perform the Chi-squared test
  chi2, p, _, _ = chi2_contingency(contingency_table)

  # Print the Chi-squared statistic and p-value
  # print(f"Chi-squared: {chi2}")
  # print(f"P-value: {p}")

  # Calculate column percentages
  col_percentages = contingency_table.div(contingency_table.sum(axis=0), axis=1) * 100

  # Create a new DataFrame for formatted annotations
  annot_data = pd.DataFrame(index=col_percentages.index, columns=col_percentages.columns)
  for i in range(contingency_table.shape[0]):
      for j in range(contingency_table.shape[1]):
          annot_data.iloc[i, j] = f"{col_percentages.iloc[i, j]:.1f}%"

  # Calculate exact confidence intervals for each cell
  confidence_intervals = pd.DataFrame(index=col_percentages.index, columns=col_percentages.columns)
  for i in range(contingency_table.shape[0]):
      for j in range(contingency_table.shape[1]):
          data = contingency_table.iloc[:, j].values
          ci = proportion_confint(data[i], nobs=sum(data), method='beta')
          confidence_intervals.iloc[i, j] = (ci[0] * 100, ci[1] * 100)

  # Increase the size of the plot
  plt.figure(figsize=(10, 6))

  # Plot the heatmap with formatted annotations
  sns.heatmap(col_percentages, annot=annot_data, fmt="", cmap="YlGnBu")

  # Add Chi-squared statistic and p-value as text annotations
  plt.text(0.5, -0.5, f"Chi-squared: {chi2:.2f}", ha='center', va='center', fontsize=12, color='black')
  plt.text(0.5, -0.7, f"P-value: {p:.4f}", ha='center', va='center', fontsize=12, color='black')

  # Annotate each cell with exact confidence interval
  for i in range(contingency_table.shape[0]):
     for j in range(contingency_table.shape[1]):
         plt.text(j + 0.5, i + 0.8, f"CI {confidence_intervals.iloc[i, j][0]:.1f}-{confidence_intervals.iloc[i, j][1]:.1f}", ha='center', va='top', fontsize=10, color='black')



  # Rotate y-axis tick labels to a horizontal position
  plt.yticks(rotation=0)
  plt.title(f'Asocierea Rezultatul tratamentului si {el}. Frecvente relative cu 95%CI')
  plt.show()

# %%
df_final.shape
# Out:
# (982, 26)

# %%
8246
4538
982
